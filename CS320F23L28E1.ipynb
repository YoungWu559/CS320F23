# %%
# Code attribution: Yiyin Shen, Tyler Caraza-Harter
# Imports
import matplotlib.pyplot as plt
from PIL import Image
import skimage
import numpy

# %%
# Open the image
image = Image.open('Spot.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x450>

# %%
# Get the 3D color array
img = numpy.asarray(image)
print(img.shape)
img[0:3, 0:3]
# Out:
# (450, 600, 3)
# array([[[212, 214, 226],
#         [212, 214, 226],
#         [212, 214, 226]],
#
#        [[212, 214, 226],
#         [214, 216, 228],
#         [214, 214, 227]],
#
#        [[210, 214, 226],
#         [212, 214, 225],
#         [212, 214, 228]]], dtype=uint8)

# %%
# Convert to grayscale
gray = skimage.color.rgb2gray(image)
print(gray.shape)
gray[0:3, 0:3]
# Out:
# (450, 600)
# array([[0.84094196, 0.84094196, 0.84094196],
#        [0.84094196, 0.8487851 , 0.84289137],
#        [0.83927529, 0.84065922, 0.84150745]])

# %%
# Plot the grayscale image
fig, ax = plt.subplots()
ax.imshow(gray, cmap = plt.cm.gray)

# %%
# Compute the pixel intensity features
x = numpy.ndarray.flatten(gray)
print(x.shape)
x[0:9]
# Out:
# (270000,)
# array([0.84094196, 0.84094196, 0.84094196, 0.84094196, 0.84150745,
#        0.83366431, 0.84094196, 0.84094196, 0.84094196])
